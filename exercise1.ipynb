# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# print this \\ doubl backslash
print("this \\\\ double backslash")
# Out:
# this \\ double backslash

# %%
# print these are /\/\/\/\/\ mountains
print("these are /\\/\\/\\/\\/\\ mountains")
# Out:
# these are /\/\/\/\/\ mountains

# %%
# he is      awesome (use escape sequence instead of manual space)
print("he\tis\t\t\tawesome")
# Out:
# he	is			awesome

# %%
#\" \n \t \' (print this as an output)
print("\\\" \\n \\t \\\'")
# Out:
# \" \n \t \'

# %%
# take three number from user side and find them average  
number1, number2, number3 = map(int, input('Enter number one, two, three separated by commas: ').split(","))
print(f" average {(number1 + number2 + number3 )/3}")
# Out:
#  average 13.0
